# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
raw_html = urlopen("https://www.photoshelter.com/explore/photographers").read()
soup_doc = BeautifulSoup(raw_html, "html.parser")

# %%
print(soup_doc.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]>         <html lang="en-US" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-US" class="no-js lt-ie9"> <![endif]-->
# <!--[if IE 9]> 		   <html lang="en-US" class="no-js lt-ie10"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="no-js" lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=320, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <title>
#    Directory of pro photographers - search for photographers by specialty | PhotoShelter
#   </title>
#   <meta content="Find a pro photographer by specialty from the PhotoShelter community. Hire a photographer or search over 70,000 photographer websites." name="Description"/>
#   <meta content="Directory of pro photographers - search for photographers by specialty" property="og:title"/>
#   <meta content="PhotoShelter" property="og:site_name"/>
# ...

# %%
soup_doc.find("ul", attrs={"id": "specialty"})
# Out:
# <ul id="specialty">
# <li><a href="/explore/photographers/ACT/specialty">Action</a></li>
# <li><a href="/explore/photographers/ADV/specialty">Adventure</a></li>
# <li><a href="/explore/photographers/ADT/specialty">Advertising</a></li>
# <li><a href="/explore/photographers/AER/specialty">Aerial</a></li>
# <li><a href="/explore/photographers/AGR/specialty">Agriculture</a></li>
# <li><a href="/explore/photographers/AME/specialty">Americana</a></li>
# <li><a href="/explore/photographers/ANI/specialty">Animals/Wildlife</a></li>
# <li><a href="/explore/photographers/ARC/specialty">Architecture/Interiors</a></li>
# <li><a href="/explore/photographers/ART/specialty">Arts/Entertainment</a></li>
# <li><a href="/explore/photographers/AUT/specialty">Auto</a></li>
# <li><a href="/explore/photographers/BEA/specialty">Beauty</a></li>
# <li><a href="/explore/photographers/CEL/specialty">Celebrity</a></li>
# <li><a href="/explore/photographers/CHI/specialty">Children</a></li>
# ...

# %%
first_link = soup_doc.find('a')
get_url = first_link['href']
print(get_url)
# Out:
# http://www.photoshelter.com/features/
